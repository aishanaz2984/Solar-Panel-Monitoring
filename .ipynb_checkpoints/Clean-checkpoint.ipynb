# %%
# import library
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

from keras.models import Sequential
from keras import models, layers
import keras
import tensorflow 
import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
from tensorflow.python.client import device_lib
print(device_lib.list_local_devices())
# Out:
# [name: "/device:CPU:0"
# device_type: "CPU"
# memory_limit: 268435456
# locality {
# }
# incarnation: 424646796316024732
# ]

# %%
data = pd.read_csv("temp_matrix (25).csv")
#check the data types
data.dtypes
# Out:
# timestamp        int64
# date            object
# time            object
# day             object
# irradiance     float64
# temperature    float64
# 0              float64
# 1              float64
# 2              float64
# 3              float64
# 4              float64
# 5              float64
# 6              float64
# 7              float64
# 8              float64
# 9              float64
# 10             float64
# 11             float64
# 12             float64
# 13             float64
# 14             float64
# 15             float64
# 16             float64
# 17             float64
# 18             float64
# 19             float64
# 20             float64
# 21             float64
# 22             float64
# 23             float64
# 24             float64
# 25             float64
# 26             float64
# 27             float64
# 28             float64
# 29             float64
# 30             float64
# 31             float64
# pmax           float64
# SCC              int64
# panel           object
# dtype: object

# %%
#clean data:
clean = data[data.panel=='clean']

#seperating data into frames:

#These are columns that don't need to be normalized
clean1 = clean[['timestamp','date','time','day','panel']]

#everything else minus the timestamp column does need to be normalized
clean2 = clean.select_dtypes(include = ['float64','int64'])
clean2 = clean2.drop(columns=['timestamp'])
clean2
# Out:
#       irradiance  temperature       0   1   2         3   4       5       6  \
# 0         557.80        28.21  31.463 NaN NaN  28.36625 NaN  30.656  29.605
# 2         787.00        33.99  45.556 NaN NaN  46.98625 NaN  47.513  48.333
# 4         916.77        32.31  49.921 NaN NaN  52.91900 NaN  52.556  53.696
# 6        1033.98        34.46  55.106 NaN NaN       NaN NaN  56.144  56.764
# 8        1030.84        35.25  55.494 NaN NaN  55.81500 NaN  55.433  55.040
# ...          ...          ...     ...  ..  ..       ...  ..     ...     ...
# 3010        3.14        38.30     NaN NaN NaN       NaN NaN     NaN     NaN
# 3012        3.14        38.30     NaN NaN NaN       NaN NaN     NaN     NaN
# 3014        3.14        38.30     NaN NaN NaN       NaN NaN     NaN     NaN
# 3016        3.14        38.30     NaN NaN NaN       NaN NaN     NaN     NaN
# 3018        3.14        38.30     NaN NaN NaN       NaN NaN     NaN     NaN
#
#        7  ...  24      25      26  27      28  29  30       31       pmax  \
# 0    NaN  ... NaN  26.068  25.936 NaN  26.624 NaN NaN  25.9125   8801.920
# 2    NaN  ... NaN  46.507  47.690 NaN  44.890 NaN NaN  47.0325  56452.320
# 4    NaN  ... NaN  51.588  53.025 NaN  49.340 NaN NaN  52.6700  61858.730
# 6    NaN  ... NaN  55.483  56.408 NaN  53.876 NaN NaN      NaN  66282.240
# 8    NaN  ... NaN  53.158  53.786 NaN  51.770 NaN NaN  52.9100  67181.928
# ...   ..  ...  ..     ...     ...  ..     ...  ..  ..      ...        ...
# 3010 NaN  ... NaN     NaN     NaN NaN     NaN NaN NaN      NaN  43498.806
# 3012 NaN  ... NaN     NaN     NaN NaN     NaN NaN NaN      NaN  32653.666
# 3014 NaN  ... NaN     NaN     NaN NaN     NaN NaN NaN      NaN   9643.520
# 3016 NaN  ... NaN     NaN     NaN NaN     NaN NaN NaN      NaN   1429.268
# 3018 NaN  ... NaN     NaN     NaN NaN     NaN NaN NaN      NaN      0.000
#
#        SCC
# 0      673
# 2     4520
# 4     5299
# 6     5963
# 8     5990
# ...    ...
# 3010  4026
# 3012  2777
# 3014   779
# 3016   224
# 3018     1
#
# [1510 rows x 36 columns]

# %%
#these columns are broken sensors, need to be replaced with 0's:
#01,02,04,07,12,15,16,19,24,27,29,30
clean2.update(clean2[['1','2','4','7','12','15','16','19','24','27','29','30']].fillna(0))
clean2.head()
# Out:
#    irradiance  temperature       0    1    2         3    4       5       6  \
# 0      557.80        28.21  31.463  0.0  0.0  28.36625  0.0  30.656  29.605
# 2      787.00        33.99  45.556  0.0  0.0  46.98625  0.0  47.513  48.333
# 4      916.77        32.31  49.921  0.0  0.0  52.91900  0.0  52.556  53.696
# 6     1033.98        34.46  55.106  0.0  0.0       NaN  0.0  56.144  56.764
# 8     1030.84        35.25  55.494  0.0  0.0  55.81500  0.0  55.433  55.040
#
#      7  ...   24      25      26   27      28   29   30       31       pmax  \
# 0  0.0  ...  0.0  26.068  25.936  0.0  26.624  0.0  0.0  25.9125   8801.920
# 2  0.0  ...  0.0  46.507  47.690  0.0  44.890  0.0  0.0  47.0325  56452.320
# 4  0.0  ...  0.0  51.588  53.025  0.0  49.340  0.0  0.0  52.6700  61858.730
# 6  0.0  ...  0.0  55.483  56.408  0.0  53.876  0.0  0.0      NaN  66282.240
# 8  0.0  ...  0.0  53.158  53.786  0.0  51.770  0.0  0.0  52.9100  67181.928
#
#     SCC
# 0   673
# 2  4520
# 4  5299
# 6  5963
# 8  5990
#
# [5 rows x 36 columns]

# %%
#replacing the remainder NaNs with meaningful values (not 0s)
#by default this will be a linear interpolation unless a different method is specified

new_clean2 = clean2.interpolate()
new_clean2
# Out:
#       irradiance  temperature        0    1    2         3    4        5  \
# 0         557.80        28.21  31.4630  0.0  0.0  28.36625  0.0  30.6560
# 2         787.00        33.99  45.5560  0.0  0.0  46.98625  0.0  47.5130
# 4         916.77        32.31  49.9210  0.0  0.0  52.91900  0.0  52.5560
# 6        1033.98        34.46  55.1060  0.0  0.0  54.36700  0.0  56.1440
# 8        1030.84        35.25  55.4940  0.0  0.0  55.81500  0.0  55.4330
# ...          ...          ...      ...  ...  ...       ...  ...      ...
# 3010        3.14        38.30  35.4225  0.0  0.0  35.53250  0.0  35.3775
# 3012        3.14        38.30  35.4225  0.0  0.0  35.53250  0.0  35.3775
# 3014        3.14        38.30  35.4225  0.0  0.0  35.53250  0.0  35.3775
# 3016        3.14        38.30  35.4225  0.0  0.0  35.53250  0.0  35.3775
# 3018        3.14        38.30  35.4225  0.0  0.0  35.53250  0.0  35.3775
#
#             6    7  ...   24      25       26   27      28   29   30       31  \
# 0     29.6050  0.0  ...  0.0  26.068  25.9360  0.0  26.624  0.0  0.0  25.9125
# 2     48.3330  0.0  ...  0.0  46.507  47.6900  0.0  44.890  0.0  0.0  47.0325
# 4     53.6960  0.0  ...  0.0  51.588  53.0250  0.0  49.340  0.0  0.0  52.6700
# 6     56.7640  0.0  ...  0.0  55.483  56.4080  0.0  53.876  0.0  0.0  52.7900
# 8     55.0400  0.0  ...  0.0  53.158  53.7860  0.0  51.770  0.0  0.0  52.9100
# ...       ...  ...  ...  ...     ...      ...  ...     ...  ...  ...      ...
# 3010  35.3775  0.0  ...  0.0  35.095  35.0775  0.0  35.190  0.0  0.0  34.9875
# 3012  35.3775  0.0  ...  0.0  35.095  35.0775  0.0  35.190  0.0  0.0  34.9875
# 3014  35.3775  0.0  ...  0.0  35.095  35.0775  0.0  35.190  0.0  0.0  34.9875
# 3016  35.3775  0.0  ...  0.0  35.095  35.0775  0.0  35.190  0.0  0.0  34.9875
# 3018  35.3775  0.0  ...  0.0  35.095  35.0775  0.0  35.190  0.0  0.0  34.9875
#
#            pmax   SCC
# 0      8801.920   673
# 2     56452.320  4520
# 4     61858.730  5299
# 6     66282.240  5963
# 8     67181.928  5990
# ...         ...   ...
# 3010  43498.806  4026
# 3012  32653.666  2777
# 3014   9643.520   779
# 3016   1429.268   224
# 3018      0.000     1
#
# [1510 rows x 36 columns]

# %%
#concatinating the dataframes:

clean_df = pd.concat([clean1, new_clean2], axis=1)

# %%
#seperating the newly revised data into frames for the independent & dependent variables
#the colon indicates all rows, and '00':'31' indicates all the columns from 00 to 31

clean_ind = clean_df.loc[:,'0':'31'] 
clean_dep = clean_df.loc[:,'pmax']

#reshaping the independent dataframe into 2D
clean_ind = clean_ind.to_numpy() #converting it to a numpy array
clean_ind[0].reshape(-1,4)


print(clean_ind.ndim)

#reshaping the dependent dataframes into 1D with the first value matching the first value of the 2D array
clean_dep = clean_dep.to_numpy() #converting it to a numpy array
clean_dep = clean_dep.reshape(-1,1)
print(clean_dep.ndim)
# Out:
# 2
# 2

# %%
#Splitting the data into the Training and the Testing set
X_train,X_test,y_train,y_test,=train_test_split(clean_ind,clean_dep,test_size=0.2,random_state=0)

# %%
print(X_train)
# Out:
# [[58.983       0.          0.         ...  0.          0.
#   61.57777778]
#  [35.4225      0.          0.         ...  0.          0.
#   34.9875    ]
#  [35.4225      0.          0.         ...  0.          0.
#   34.9875    ]
#  ...
#  [35.4225      0.          0.         ...  0.          0.
#   34.9875    ]
#  [57.513       0.          0.         ...  0.          0.
#   53.935     ]
#  [36.1425      0.          0.         ...  0.          0.
#   35.6875    ]]

# %%
#Feature scaleing using the fit transform function to calibrate the measurement so that the training and test data have a similar shape

#create MinMaxScaler objects
MinMaxScaler = preprocessing.MinMaxScaler(feature_range=(0,1))
X_train = MinMaxScaler.fit_transform(X_train)
X_test = MinMaxScaler.fit_transform(X_test)

y_train = MinMaxScaler.fit_transform(y_train)
y_test = MinMaxScaler.fit_transform(y_test)

# %%
X_train = X_train.reshape(X_train.shape[0], 8,4,1)
X_train.ndim
# Out:
# 4

# %%
X_test = X_test.reshape(X_test.shape[0], 8,4,1)
X_test.ndim
# Out:
# 4

# %%
y_train.ndim
# Out:
# 2

# %%
y_test.ndim
# Out:
# 2

# %%
#custome loss functions for r_square
def r_square(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return (1 - SS_res/(SS_tot + K.epsilon()))

def r_square_loss(y_true, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square(y_true - y_pred)) 
    SS_tot = K.sum(K.square(y_true - K.mean(y_true))) 
    return 1 - ( 1 - SS_res/(SS_tot + K.epsilon()))

# %%
#Instantiate an empty model
model = Sequential()

# C1 Convolutional Layer
model.add(layers.Conv2D(6, kernel_size=(2, 2), strides=(1, 1), activation='relu', input_shape=(8,4,1), padding="same"))

# S2 Pooling Layer
#model.add(layers.AveragePooling2D(pool_size=(2, 2), strides=(1, 1), padding='valid'))

# C3 Convolutional Layer
model.add(layers.Conv2D(16, kernel_size=(2, 2), strides=(1, 1), activation='relu', padding='valid'))

# C5 Fully Connected Convolutional Layer
model.add(layers.Conv2D(120, kernel_size=(2, 2), strides=(1, 1), activation='relu', padding='valid'))

#Flatten the CNN output so that we can connect it with fully connected layers
model.add(layers.Flatten())
    
# FC6 Fully Connected Layer
model.add(layers.Dense(84, activation='relu'))

#Output Layer with softmax activation
model.add(layers.Dense(1, activation='relu'))

# Compile the model
model.compile(loss='mean_squared_error', optimizer='adam', metrics=["mse", r_square])

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 8, 4, 6)           30
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 7, 3, 16)          400
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 6, 2, 120)         7800
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 1440)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 84)                121044
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 85
# =================================================================
# Total params: 129,359
# Trainable params: 129,359
# Non-trainable params: 0
# _________________________________________________________________

# %%
hist = model.fit(x=X_train,y=y_train, epochs=100, batch_size= 10, validation_data=(X_test, y_test), verbose=1)
# Out:
# Train on 1208 samples, validate on 302 samples
# Epoch 1/100
# 1208/1208 [==============================] - 0s 376us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.2869 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 2/100
# 1208/1208 [==============================] - 0s 183us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.3993 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 3/100
# 1208/1208 [==============================] - 0s 192us/step - loss: 0.3086 - mse: 0.3086 - r_square: -5.3084 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 4/100
# 1208/1208 [==============================] - 0s 167us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.6907 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 5/100
# 1208/1208 [==============================] - 0s 178us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.0116 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 6/100
# 1208/1208 [==============================] - 0s 178us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.3326 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 7/100
# 1208/1208 [==============================] - 0s 178us/step - loss: 0.3086 - mse: 0.3086 - r_square: -3.9574 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 8/100
# 1208/1208 [==============================] - 0s 180us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.2035 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 9/100
# 1208/1208 [==============================] - 0s 178us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.4655 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 10/100
# 1208/1208 [==============================] - 0s 182us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.7841 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 11/100
# 1208/1208 [==============================] - 0s 178us/step - loss: 0.3086 - mse: 0.3086 - r_square: -3.7037 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 12/100
# 1208/1208 [==============================] - 0s 150us/step - loss: 0.3086 - mse: 0.3086 - r_square: -3.9942 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 13/100
# 1208/1208 [==============================] - 0s 151us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.0566 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 14/100
# 1208/1208 [==============================] - 0s 159us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4
- val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 84/100
# 1208/1208 [==============================] - 0s 168us/step - loss: 0.3086 - mse: 0.3086 - r_square: -3.8076 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 85/100
# 1208/1208 [==============================] - 0s 174us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.6986 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 86/100
# 1208/1208 [==============================] - 0s 152us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.6046 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 87/100
# 1208/1208 [==============================] - 0s 147us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.2200 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 88/100
# 1208/1208 [==============================] - 0s 154us/step - loss: 0.3086 - mse: 0.3086 - r_square: -3.8784 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 89/100
# 1208/1208 [==============================] - 0s 150us/step - loss: 0.3086 - mse: 0.3086 - r_square: -3.8211 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 90/100
# 1208/1208 [==============================] - 0s 148us/step - loss: 0.3086 - mse: 0.3086 - r_square: -3.7567 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 91/100
# 1208/1208 [==============================] - 0s 147us/step - loss: 0.3086 - mse: 0.3086 - r_square: -3.8306 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 92/100
# 1208/1208 [==============================] - 0s 145us/step - loss: 0.3086 - mse: 0.3086 - r_square: -3.7307 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 93/100
# 1208/1208 [==============================] - 0s 141us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.1509 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 94/100
# 1208/1208 [==============================] - 0s 149us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.0593 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 95/100
# 1208/1208 [==============================] - 0s 149us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.6124 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 96/100
# 1208/1208 [==============================] - 0s 141us/step - loss: 0.3086 - mse: 0.3086 - r_square: -3.9529 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 97/100
# 1208/1208 [==============================] - 0s 144us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.3786 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 98/100
# 1208/1208 [==============================] - 0s 140us/step - loss: 0.3086 - mse: 0.3086 - r_square: -3.6823 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 99/100
# 1208/1208 [==============================] - 0s 141us/step - loss: 0.3086 - mse: 0.3086 - r_square: -5.8819 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740
# Epoch 100/100
# 1208/1208 [==============================] - 0s 149us/step - loss: 0.3086 - mse: 0.3086 - r_square: -4.2400 - val_loss: 0.3405 - val_mse: 0.3405 - val_r_square: -3.6740

# %%
test_score = model.evaluate(X_test, y_test)
print("Test loss {:.4f}, accuracy {:.2f}%".format(test_score[0], test_score[1] * 100))
# Out:
# 302/302 [==============================] - 0s 30us/step
# Test loss 0.3405, accuracy 34.05%

# %%
f, ax = plt.subplots()
ax.plot([None] + hist.history['mse'], 'o-')
ax.plot([None] + hist.history['val_mse'], 'x-')
# Plot legend and use the best location automatically: loc = 0.
ax.legend(['Train mse', 'Validation mse'], loc = 0)
ax.set_title('Training/Validation acc per Epoch')
ax.set_xlabel('Epoch')
ax.set_ylabel('mse')
# Out:
# Text(0, 0.5, 'mse')

# %%
f, ax = plt.subplots()
ax.plot([None] + hist.history['loss'], 'o-')
ax.plot([None] + hist.history['val_loss'], 'x-')
# Plot legend and use the best location automatically: loc = 0.
ax.legend(['Train Loss', 'Validation Loss'], loc = 0)
ax.set_title('Training/Validation Loss per Epoch')
ax.set_xlabel('Epoch')
ax.set_ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
#when you compile the model, add your custom loss function as a metric
model.compile(loss='mse', optimizer='adam', metrics=['mse', r_square])

# %%
#plot from history
plt.plot(hist.history['r_square'])
plt.plot(hist.history['val_r_square'])
plt.title('R Square')
plt.ylabel('r_square')
plt.xlabel('epoch')
plt.legend(['train', 'validation'], loc='upper left')
